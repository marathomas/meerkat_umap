# %% [markdown]
# # **Misclassification spotter**

# %% [markdown]
# Example application of spectrogram approach to identify misclassified audios in a dataset

# %% [markdown]
# # Prerequisites

# %% [markdown]
# ## Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Libraries

# %%
import os
import pandas as pd
import librosa.display
import numpy as np
from pandas.core.common import flatten
import datetime
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
import scipy
import pickle

# %% [markdown]
# ## Constants

# %%
#PROJECT_PATH = '/content/drive/My Drive/meerkat/misclassi_experiment/full_cleaned/'
#PROJECT_PATH = '/content/drive/My Drive/meerkat/misclassi_experiment/balanced_cleaned/'
PROJECT_PATH = '/content/drive/My Drive/meerkat/misclassi_experiment/no_hybrids/'

FIGURES = PROJECT_PATH+"figures/"

os.chdir(PROJECT_PATH)

# %%
dirs2create = ['wavs', 'imgs', 'nb_imgs', 'nb_wavs']

for dirpath in dirs2create:
  if not os.path.exists(dirpath):
    os.mkdir(dirpath)

# %% [markdown]
# ## Functions

# %%
# Function that pads a spectrogram with zeros to a certain length
# Input: spectrogram (2D np array)
#        maximal length (Integer)
# Output: Padded spectrogram (2D np array)

def pad_spectro(spec,maxlen):
  padding = maxlen - spec.shape[1]
  z = np.zeros((spec.shape[0],padding))
  padded_spec=np.append(spec, z, axis=1)
  return padded_spec

# %% [markdown]
# # Spotter

# %% [markdown]
# ## Load dataset

# %% [markdown]
# Using the meerkat dataset from 12.01.2021
#
# I've already created the spectrograms in the file `My Drive/meerkat/Vlad/Vlad_meerkat_sequences.ipynb`

# %%
df = pd.read_pickle("/content/drive/My Drive/meerkat/Vlad/all_calls.pkl")
df
# Out:
#       Unnamed: 0  ...                    denoised_stretched_spectrograms
# 0        1:20363  ...  [[-0.09523499, -0.045557022, -0.019791603, -0....
# 1        1:20364  ...  [[0.44095325, 0.43950438, 0.4410069, 0.4418924...
# 2        1:20365  ...  [[0.45829523, 0.44515342, 0.43293548, 0.421509...
# 3        1:20366  ...  [[0.47811228, 0.4749245, 0.48041034, 0.4846502...
# 4        1:20367  ...  [[0.073192954, 0.06809378, 0.05868709, 0.04939...
# ...          ...  ...                                                ...
# 23921    2:38386  ...  [[0.18575692, 0.122386456, 0.11364937, 0.11689...
# 23922    2:27223  ...  [[1.2937286, 1.2324724, 1.224149, 1.1897676, 1...
# 23923    2:27224  ...  [[0.53526694, 0.6120646, 0.6553303, 0.6866945,...
# 23924    2:27841  ...  [[0.8369186, 0.8234837, 0.8457298, 0.8710468, ...
# 23925    2:27225  ...  [[1.0135075, 1.0666385, 1.0845562, 1.091213, 1...
#
# [23925 rows x 50 columns]

# %% [markdown]
# ## Clean dataset

# %% [markdown]
# ### Long calls

# %% [markdown]
# Need to remove very long calls, otherwise padding is too computationally costly.

# %%
df.shape
# Out:
# (23925, 50)

# %%
n, bins, patches = plt.hist(df.duration)

# %%
df = df.loc[df['duration'] <= 0.5,:]
df.shape
# Out:
# (23733, 50)

# %% [markdown]
# ### Noisy calls etc

# %% [markdown]
# This time, will also remove noisy or nonfocal calls.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'entryName', 't0File', 'duration', 'date',
#        't0_idx_dayTimeline', 't0GPS_UTC', 'tEndGPS_UTC', 'tMidGPS_UTC', 'ind',
#        'fileName', 'callID', 'callType', 'isCall', 'nonFocal', 'hybrid',
#        'noisy', 'unsureType', 'unsureFocal', 'closest_neigh_dist',
#        'closest_neigh_id', 'nbr_neigh_below_5m', 'id_neigh_below_5m',
#        'nbr_neigh_below_10m', 'id_neigh_below_10m', 'x_emitted', 'y_emitted',
#        'labeller', 'verifier', 'color', 'hyb', 'stn_call_type', 'type_group',
#        't0.numeric', 'tf.numeric', 'skip', 'lag', 'seq', 't_type', 'dyad',
#        'cc_seq', 'UID', 'starts', 'ends', 'samplerate_hz', 'raw_audio',
#        'spectrograms', 'stretched_spectrograms', 'denoised_spectrograms',
#        'denoised_stretched_spectrograms'],
#       dtype='object')

# %%
df.nonFocal.value_counts() # ok all are focal
# Out:
# 0    23733
# Name: nonFocal, dtype: int64

# %%
df.unsureFocal.value_counts()  # ok can remove these 2.119 calls
# Out:
# 0    21614
# 1     2119
# Name: unsureFocal, dtype: int64

# %%
df.noisy.value_counts() # ok can remove these 2.184 calls
# Out:
# 0    21549
# 1     2184
# Name: noisy, dtype: int64

# %%
df.isCall.value_counts() # ok all are calls
# Out:
# 1    23733
# Name: isCall, dtype: int64

# %% [markdown]
# Remove:

# %%
df = df.loc[df['unsureFocal'] == 0,:]
df = df.loc[df['noisy'] == 0,:]
df.shape
# Out:
# (19604, 50)

# %%
df.hybrid.value_counts()
# Out:
# 0    7812
# 1     501
# Name: hybrid, dtype: int64

# %%
# Remove hybrid/fused

df = df.loc[df['hybrid'] != 1,:]
df.shape
# Out:
# (18401, 50)

# %% [markdown]
# ### Class imbalance

# %%
df.type_group.value_counts()
# Out:
# cc     12546
# sn      4568
# mo       786
# soc      656
# al       468
# agg      311
# ld       161
# unk      108
# Name: type_group, dtype: int64

# %%
wo_cc_df = df[df.type_group != 'cc']
cc_df = df[df.type_group == 'cc']
cc_subset = cc_df.sample(frac=0.1, replace=False, random_state=1)
df = pd.concat((wo_cc_df, cc_subset), ignore_index=False, axis=0)

df.type_group.value_counts()
# Out:
# sn     4568
# cc     1255
# mo      786
# soc     656
# al      468
# agg     311
# ld      161
# unk     108
# Name: type_group, dtype: int64

# %% [markdown]
# ## Find nearest neighbors

# %%
specs = df.denoised_spectrograms.values
maxlen= np.max([spec.shape[1] for spec in specs])
flattened_specs = [pad_spectro(spec, maxlen).flatten() for spec in specs]
data = np.asarray(flattened_specs)

# %%
# or use NOT denoised specs
from sklearn.preprocessing import StandardScaler

specs = df.spectrograms.values
maxlen= np.max([spec.shape[1] for spec in specs])
flattened_specs = [pad_spectro(spec, maxlen).flatten() for spec in specs]
data = np.asarray(flattened_specs)

data = StandardScaler().fit_transform(pd.DataFrame(data).transpose())
data = np.asarray(data.transpose())

# %%
k=5

nbrs = NearestNeighbors(metric='euclidean',n_neighbors=k+1, algorithm='brute').fit(data)
distances, indices = nbrs.kneighbors(data)

# need to remove the first neighbor, because that is the datapoint itself
indices = indices[:,1:]  
distances = distances[:,1:]

# %%
label_col = 'type_group'
labels = df[label_col].tolist()

# %%
wrong_neighbors = []
wrong_neighbors_row_num = []
wrong_datapoint = []
wrong_rownum = []

for i in range(df.shape[0]):
  datapoint_label = labels[i]
  neighbors = indices[i]
  neighbor_labels = [labels[x] for x in neighbors]

  if datapoint_label not in neighbor_labels:
    wrong_neighbors.append(neighbor_labels)
    wrong_neighbors_row_num.append(neighbors)
    wrong_datapoint.append(datapoint_label)
    wrong_rownum.append(i)

# %%
len(wrong_neighbors)
# Out:
# 688

# %%
wrong_df = pd.DataFrame(list(zip(wrong_rownum, wrong_datapoint)), 
               columns =['row_num', 'call_lable']) 

wrong_neighbors_arr = np.vstack(wrong_neighbors)

for i in range(wrong_neighbors_arr.shape[1]):
  col_name = "neighbor_"+str(i+1)
  wrong_df[col_name] = wrong_neighbors_arr[:,i]

wrong_neighbors_row_num_arr = np.vstack(wrong_neighbors_row_num)

for i in range(wrong_neighbors_row_num_arr.shape[1]):
  col_name = "neighbor_"+str(i+1)+"_rownum"
  wrong_df[col_name] = wrong_neighbors_row_num_arr[:,i]
  
wrong_df
# Out:
#      row_num call_lable  ... neighbor_4_rownum neighbor_5_rownum
# 0         24         sn  ...               967              1012
# 1         25         sn  ...              3821              1439
# 2         26         mo  ...               434              2562
# 3         44         sn  ...              1926              6213
# 4         53        soc  ...             14053              2374
# ..       ...        ...  ...               ...               ...
# 683    18360         cc  ...              1215               910
# 684    18362        soc  ...              4842             17054
# 685    18365         cc  ...             11410              9518
# 686    18385         cc  ...              1382              6646
# 687    18388        unk  ...               591              3848
#
# [688 rows x 12 columns]

# %% [markdown]
# ### Descriptive statistics

# %%
wrong_df['call_lable'].value_counts()
# Out:
# soc    200
# al     114
# cc      85
# agg     67
# unk     65
# ld      59
# mo      52
# sn      46
# Name: call_lable, dtype: int64

# %%
w = pd.DataFrame(wrong_df['call_lable'].value_counts())
w.sort_index(inplace=True)

a = pd.DataFrame(df[label_col].value_counts())
a.sort_index(inplace=True)

# %%
tab = pd.DataFrame({'mispositioned': w['call_lable'], 'overall': a[label_col], 'percentage': 100*(w['call_lable']/a[label_col])})
tab
# Out:
#      mispositioned  overall  percentage
# agg             67      306   21.895425
# al             114      467   24.411135
# cc              85    11759    0.722851
# ld              59      161   36.645963
# mo              52      679    7.658321
# sn              46     4300    1.069767
# soc            200      621   32.206119
# unk             65      108   60.185185

# %%
fig = plt.figure(figsize=(10,5))
labelcounts = pd.DataFrame(df[label_col].value_counts())
labelcounts.sort_index(inplace=True)
pal = sns.color_palette("Set2", n_colors=len(labelcounts.index))
plt.barh(labelcounts.index, labelcounts[label_col].values, color = pal)
plt.barh(labelcounts.index, tab.mispositioned.values, color = 'black')
plt.xlabel("N of calls")
plt.xlim(0,16500)
for index, value in enumerate(tab.mispositioned.values):
    plt.text(15000, index, str(round(tab.loc[tab.index[index],'percentage'],1))+" %")

# %% [markdown]
# ### Clear cases

# %% [markdown]
# Identify "clear" cases, where all neighbors are of the same label type.

# %%
nb_cols=[]
for i in range(k):
  nb_cols.append('neighbor_'+str(i+1))
nb_cols
# Out:
# ['neighbor_1', 'neighbor_2', 'neighbor_3', 'neighbor_4', 'neighbor_5']

# %%
clear_cases = []

for i in range(wrong_df.shape[0]):
  nbs = wrong_df.loc[i,nb_cols].tolist()
  if len(set(nbs))==1:
    clear_cases.append('yes')
  else:
    clear_cases.append('no')

# %%
wrong_df['clear_case'] = clear_cases
wrong_df.clear_case.value_counts()
# Out:
# yes    376
# no     312
# Name: clear_case, dtype: int64

# %% [markdown]
# Okay, for 603 calls, there seems to be a clear mislabeling. Plot some example calls:

# %% [markdown]
# ### Plot example misclassified calls

# %%
wrong_df.head()
# Out:
#    row_num call_lable  ... neighbor_5_rownum clear_case
# 0       24         sn  ...              1012         no
# 1       25         sn  ...              1439        yes
# 2       26         mo  ...              2562         no
# 3       44         sn  ...              6213         no
# 4       53        soc  ...              2374        yes
#
# [5 rows x 13 columns]

# %% [markdown]
# Remove unknown calls and only select clear cases

# %%
wrong_subset = wrong_df.loc[wrong_df['clear_case']=='yes']
wrong_subset = wrong_subset.loc[wrong_subset['call_lable']!='unk']

# Need to reset index, else won't be able to accces ith row of original dataframe
df.reset_index(inplace=True)

calltypes = sorted(list(set(wrong_subset['call_lable'])))
calltypes
# Out:
# ['agg', 'al', 'cc', 'ld', 'mo', 'sn', 'soc']

# %%
for calltype in calltypes:

  fig = plt.figure(figsize=(14,6))
  fig_name = 'NN_misclass_Viz_'+calltype
  p=1

  subset_df = wrong_subset.loc[wrong_subset['call_lable']==calltype,:]

  # randomly choose 4
  examples = subset_df.sample(n=4, random_state=2204)
  examples.reset_index(inplace=True)
  
  for i in range(examples.shape[0]):
    ori_rownum = examples.loc[i,'row_num']
    spec = df.loc[ori_rownum,'denoised_spectrograms']
    #spec = df.loc[ori_rownum,'spectrograms']
    plt.subplot(4, 6, p)
    plt.imshow(spec, interpolation='nearest', origin='lower', aspect='equal') 
    plt.axis('off')
    original_name = df.loc[ori_rownum,'entryName']
    plt.title(calltype+" ("+original_name+")")
    p=p+1

    for neighbor in range(1,6):
      neighbor_label = examples.loc[i,'neighbor_'+str(neighbor)]
      nb_rownum = examples.loc[i,'neighbor_'+str(neighbor)+'_rownum']
      neighbor_spec = df.loc[nb_rownum,'denoised_spectrograms']
      #neighbor_spec = df.loc[nb_rownum,'spectrograms']
      dist = scipy.spatial.distance.euclidean(data[ori_rownum,:], data[nb_rownum,:])
      plt.subplot(4, 6, p)
      plt.imshow(neighbor_spec, interpolation='nearest', origin='lower', aspect='equal') 
      plt.axis('off')
      plt.title(examples.loc[i,'neighbor_'+str(neighbor)]+" ("+str(round(dist,1))+")")
      p=p+1
        
  plt.tight_layout() 
  plt.savefig(FIGURES+fig_name)

# %% [markdown]
# ### Some extra investigation

# %%
# the last alarm call looks weird
subset_df = wrong_subset.loc[wrong_subset['call_lable']=='al',:]
# randomly choose 4
examples = subset_df.sample(n=4, random_state=2204)
examples.reset_index(inplace=True)
examples
# Out:
#    index  row_num call_lable  ... neighbor_4_rownum neighbor_5_rownum clear_case
# 0    636    14428         al  ...             14057             15036        yes
# 1    304     8532         al  ...              4204              1407         no
# 2    196     5497         al  ...              6435              7922        yes
# 3    477    11513         al  ...               865             13732        yes
#
# [4 rows x 14 columns]

# %%
sub_df = df.loc[df['type_group']=='al',:]
al_examples = sub_df.sample(n=4)
al_examples.reset_index(inplace=True)
al_examples

# %%
ori_rownum = examples.loc[3,'row_num']
ori_spec = df.loc[ori_rownum,'denoised_spectrograms']
plt.subplot(1, 5, 1)
plt.imshow(ori_spec, interpolation='nearest', origin='lower', aspect='auto') 
plt.title('original')
p=2

for i in range(al_examples.shape[0]):
  spec = al_examples.loc[i,'denoised_spectrograms']
  spec_rownum = al_examples.loc[i,'level_0']
  plt.subplot(1, 5, p)
  plt.imshow(spec, interpolation='nearest', origin='lower', aspect='auto') 

  dist = scipy.spatial.distance.euclidean(data[ori_rownum,:], data[spec_rownum,:])
  plt.title(str(round(dist,1)))

  plt.axis('off')
  p=p+1

plt.tight_layout()

# %%
ori_spec
# Out:
# array([[  8.472408  ,   6.4314117 ,   5.346321  , ...,   8.380409  ,
#           9.5167885 ,  10.9277725 ],
#        [  1.7064629 ,   0.4923706 ,   0.20690155, ...,  -6.065605  ,
#           0.36676407,   6.808571  ],
#        [  3.4744377 ,   1.0293121 ,  -1.0690231 , ...,  -6.506508  ,
#          -0.03921127,   5.0680695 ],
#        ...,
#        [-14.826313  , -17.20501   , -17.157974  , ..., -15.432114  ,
#          -9.261868  ,  -2.1686172 ],
#        [-13.004444  , -15.271576  , -14.73291   , ..., -16.81099   ,
#         -12.978954  ,  -7.064995  ],
#        [ -7.796154  , -10.269287  , -11.849358  , ..., -16.490593  ,
#         -13.854244  ,  -8.784309  ]], dtype=float32)

# %%
spec = al_examples.loc[0,'denoised_spectrograms']
spec
# Out:
# array([[ 19.302673 ,  18.619991 ,  17.363012 , ...,  13.536249 ,
#          12.532619 ,  15.115276 ],
#        [ 17.46669  ,  16.90926  ,  15.880199 , ...,  11.556288 ,
#          14.002413 ,  17.680397 ],
#        [ 10.6462345,   9.870859 ,   9.132423 , ...,  11.086622 ,
#          12.116308 ,  14.249359 ],
#        ...,
#        [ -4.066166 ,  -4.145607 ,  -4.114586 , ...,  -8.736698 ,
#         -13.683758 , -15.305542 ],
#        [ -7.06728  ,  -7.191498 ,  -7.0033646, ..., -17.813969 ,
#         -16.635471 , -13.138451 ],
#        [ -5.0014534,  -5.57547  ,  -5.5682755, ..., -16.103603 ,
#         -18.57185  , -16.607231 ]], dtype=float32)

# %%
ori_padded = np.asarray(pad_spectro(ori_spec, maxlen).flatten())
spec_padded = np.asarray(pad_spectro(spec, maxlen).flatten())
scipy.spatial.distance.euclidean(ori_padded, spec_padded)
# Out:
# 802.5106451298269

# %% [markdown]
# ### Random select calls for manual assignment

# %% [markdown]
# From the subset of clearly misclassified calls, select a reasonable amount that Vlad and Baptiste can go through manually and check.

# %%
random_subset = wrong_subset.sample(n=50, random_state=1)
random_subset
# Out:
#      row_num call_lable  ... neighbor_5_rownum clear_case
# 40       796        soc  ...              8184        yes
# 535     7775         cc  ...               332        yes
# 160     2670         ld  ...              4573        yes
# 91      1899         ld  ...              1186        yes
# 502     7192         cc  ...               367        yes
# 509     7280         cc  ...              2390        yes
# 253     3841        soc  ...              7340        yes
# 347     5400         al  ...              5827        yes
# 73      1523         al  ...              1193        yes
# 128     2373         sn  ...              7618        yes
# 310     4503         al  ...              3879        yes
# 137     2430        soc  ...              6834        yes
# 17       314         al  ...               228        yes
# 318     4810        soc  ...              4497        yes
# 206     3114         al  ...               624        yes
# ...

# %%
random_subset['denoised_spectrograms'] = [df.loc[x,'denoised_spectrograms'] for x in random_subset.row_num]
random_subset['spectrograms'] = [df.loc[x,'spectrograms'] for x in random_subset.row_num]
random_subset['raw_audio'] = [df.loc[x,'raw_audio'] for x in random_subset.row_num]
random_subset['samplerate_hz'] = [df.loc[x,'samplerate_hz'] for x in random_subset.row_num]
random_subset['UID'] = [df.loc[x,'UID'] for x in random_subset.row_num]
random_subset['entryName'] = [df.loc[x,'entryName'] for x in random_subset.row_num]


random_subset['nb_audio'] = [df.loc[x,'raw_audio'] for x in random_subset.neighbor_1_rownum]
random_subset['nb_samplerate_hz'] = [df.loc[x,'samplerate_hz'] for x in random_subset.neighbor_1_rownum]

# %%
for nb_num in range(1,6):
  random_subset['nb_'+str(nb_num)+'audio'] = [df.loc[x,'raw_audio'] for x in random_subset['neighbor_'+str(nb_num)+'_rownum']]
  random_subset['nb_'+str(nb_num)+'samplerate_hz'] = [df.loc[x,'samplerate_hz'] for x in random_subset['neighbor_'+str(nb_num)+'_rownum']]
  random_subset['nb_'+str(nb_num)+'denoised_spectrograms'] = [df.loc[x,'denoised_spectrograms'] for x in random_subset['neighbor_'+str(nb_num)+'_rownum']]

# %%
random_subset.reset_index(inplace=True)

# %% [markdown]
# #### Save calls

# %%
os.chdir(PROJECT_PATH)
random_subset.to_pickle('random_sub.pkl')

# %%
random_subset.to_json(PROJECT_PATH+'random_sub.json', orient = 'split', compression = 'infer', index = 'true')

# %%
random_subset = pd.read_pickle(PROJECT_PATH+'random_sub.pkl')

# %%
# if not done yet
df.reset_index(inplace=True)

# %%
random_subset.samplerate_hz.value_counts()
# Out:
# 8000     45
# 48000     4
# 44100     1
# Name: samplerate_hz, dtype: int64

# %% [markdown]
# ### Visualize examples from random subset

# %%
random_subset.call_lable.value_counts()
# Out:
# soc    23
# cc      8
# sn      5
# al      4
# mo      4
# agg     3
# ld      3
# Name: call_lable, dtype: int64

# %%
calltypes = sorted(list(set(random_subset.call_lable)))

for calltype in calltypes:

  fig = plt.figure(figsize=(14,6))
  fig_name = 'NN_misclass_Viz_rando_'+calltype
  p=1

  subset_df = random_subset.loc[random_subset['call_lable']==calltype,:]

  if subset_df.shape[0]>=2:
    # randomly choose 2
    examples = subset_df.sample(n=2, random_state=2204)
    examples.reset_index(inplace=True)
  
    for i in range(examples.shape[0]):
      ori_rownum = examples.loc[i,'row_num']
      spec = df.loc[ori_rownum,'denoised_spectrograms']
      #spec = df.loc[ori_rownum,'spectrograms']
      plt.subplot(4, 6, p)
      plt.imshow(spec, interpolation='nearest', origin='lower', aspect='equal') 
      plt.axis('off')
      original_name = df.loc[ori_rownum,'entryName']
      plt.title(calltype+" ("+original_name+") "+str(examples.loc[i,'index']))
      p=p+1

      for neighbor in range(1,6):
        neighbor_label = examples.loc[i,'neighbor_'+str(neighbor)]
        nb_rownum = examples.loc[i,'neighbor_'+str(neighbor)+'_rownum']
        neighbor_spec = df.loc[nb_rownum,'denoised_spectrograms']
        #neighbor_spec = df.loc[nb_rownum,'spectrograms']
        dist = scipy.spatial.distance.euclidean(data[ori_rownum,:], data[nb_rownum,:])
        plt.subplot(4, 6, p)
        plt.imshow(neighbor_spec, interpolation='nearest', origin='lower', aspect='equal') 
        plt.axis('off')
        plt.title(examples.loc[i,'neighbor_'+str(neighbor)]+" ("+str(round(dist,1))+")")
        p=p+1
        
    plt.tight_layout() 
    plt.savefig(FIGURES+fig_name)

# %% [markdown]
# ##### Wavs

# %%
# Need to resample all at same samplerate!!!!

import soundfile as sf
from scipy.io import wavfile
import scipy.signal as sps

SR = 8000

def write_wav(uid, data, sr):
  filename = str(uid)+'.wav'
  if sr == SR:
    sf.write(filename, data, sr, subtype='PCM_16')
  else: # resample
    print("Resampled for "+filename)
    number_of_samples = round(len(data) * float(SR) / sr)
    data = sps.resample(data, number_of_samples)
    sf.write(filename, data, SR, subtype='PCM_16')


os.chdir(PROJECT_PATH+'wavs/')
x=random_subset.apply(lambda row: write_wav(row['index'], row['raw_audio'], row['samplerate_hz']), axis=1)
# Out:
# Resampled for 283.wav
# Resampled for 122.wav
# Resampled for 446.wav
# Resampled for 179.wav
# Resampled for 169.wav

# %%
# nb wavs
os.chdir(PROJECT_PATH+'nb_wavs/')
x=random_subset.apply(lambda row: write_wav(row['index'], row['nb_audio'], row['nb_samplerate_hz']), axis=1)
# Out:
# Resampled for 91.wav
# Resampled for 73.wav
# Resampled for 128.wav
# Resampled for 111.wav
# Resampled for 30.wav
# Resampled for 94.wav

# %%
import librosa
import IPython.display as ipd

# %%
os.chdir(PROJECT_PATH+'wavs/')
data, sr = librosa.load('1130.wav', sr=None)
ipd.Audio(data=data,rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##### Spec imgs

# %%
import pylab

# works only if all have same SR ! (15.02.2021)

HOP_LEN = int(0.03*SR) # this is wrong I think
FMAX = SR/2
n_ticks=3
FFT_WIN = 0.03
FFT_HOP = FFT_WIN/8


def write_img(uid, spec):
    outname = str(uid)+".jpg" 
    plt.figure()  
    librosa.display.specshow(spec,sr=SR, hop_length=HOP_LEN , fmax=FMAX, y_axis='mel', cmap='inferno')
    n_frames = spec.shape[1]
    duration = FFT_HOP*spec.shape[1]
    step_size = round(duration/n_ticks,2)
    myticks = np.arange(0,duration, step_size)
    plt.xticks([round(x/FFT_HOP,0) for x in myticks], [str(round(x,2)) for x in myticks])

    pylab.savefig(PROJECT_PATH+'imgs/'+outname, bbox_inches=None, pad_inches=0)
    pylab.close()

#write_img('test', random_subset.loc[4,'denoised_spectrograms'])

x=random_subset.apply(lambda row: write_img(row['index'], row['denoised_spectrograms']), axis=1)

# %%
n_ticks=3
FFT_WIN = 0.03
FFT_HOP = FFT_WIN/8

for i in range(random_subset.shape[0]):
#for i in range(3):
    plt.figure(figsize=(12, 2))
    outname = str(random_subset.loc[i,'index'])+'.jpg'
    ori_rownum = random_subset.loc[i,'row_num']
    spec = df.loc[ori_rownum,'denoised_spectrograms']
    plt.subplot(1, 6, 1)
    librosa.display.specshow(spec,sr=SR, hop_length=HOP_LEN , fmax=FMAX, y_axis='mel', cmap='inferno')

    # Generate axis labels
    #n_frames = spec.shape[1]
    duration = FFT_HOP*spec.shape[1]
    step_size = round(duration/n_ticks,2)
    myticks = np.arange(0,duration, step_size)
    plt.xticks([round(x/FFT_HOP,0) for x in myticks], [str(round(x,2)) for x in myticks])

    plt.title(df.loc[ori_rownum,'type_group'])
    p=2


    for neighbor in range(1,6):
      neighbor_label = random_subset.loc[i,'neighbor_'+str(neighbor)]
      nb_rownum = random_subset.loc[i,'neighbor_'+str(neighbor)+'_rownum']
      neighbor_spec = df.loc[nb_rownum,'denoised_spectrograms']
      plt.subplot(1, 6, p)
      librosa.display.specshow(neighbor_spec,sr=SR, hop_length=HOP_LEN , fmax=FMAX, cmap='inferno')
      plt.xticks([round(x/FFT_HOP,0) for x in myticks], [str(round(x,2)) for x in myticks])
      plt.title(random_subset.loc[i,'neighbor_'+str(neighbor)])
      p=p+1

    plt.savefig(PROJECT_PATH+'nb_imgs/'+outname)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys

# %% [markdown]
# #### Info file

# %%
os.chdir(PROJECT_PATH)

random_subset[['index', 'call_lable', 'neighbor_1']].to_csv('info.csv', index=False)

# %%
x=pd.read_csv('info.csv')
x
# Out:
#     index call_lable neighbor_1
# 0     511        soc         cc
# 1    1130         cc         sn
# 2     520        soc         cc
# 3    1123         cc         sn
# 4     941        soc         cc
# 5     556         sn         cc
# 6     466         ld         cc
# 7    1131         cc         sn
# 8     495         cc         sn
# 9     836        soc         cc
# 10    925         sn         mo
# 11   1138         mo         sn
# 12    595         mo         cc
# 13    424        soc         cc
# 14   1143         cc         al
# 15    122        soc         cc
# 16    216         cc         al
# 17    261         al         mo
# 18     94         cc         sn
# 19    607        soc         cc
# 20    674        soc         sn
# 21    884        soc         cc
# 22   1054        agg         cc
# 23    152         sn         mo
# 24   1129         cc         sn
# 25   1087         cc         sn
# 26   1089         al         mo
# 27   1083         cc        agg
# ...

# %%
from IPython.display import Audio
#import IPython
data =random_subset.loc[random_subset['index']==395,:].raw_audio.values[0]
sr= random_subset.loc[random_subset['index']==395,:].samplerate_hz.values[0]
Audio(data,rate=sr)

number_of_samples = round(len(data) * float(SR) / sr)
data = sps.resample(data, number_of_samples)
Audio(data,rate=SR)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
random_subset['ind_str'] = [str(x) for x in random_subset['index']]
random_subset.sort_values(by='ind_str')
# Out:
#     index  row_num  ...              entryName ind_str
# 33   1036    22273  ...                   cc x    1036
# 22   1054    22771  ...                  agg *    1054
# 27   1083    22969  ...                   cc x    1083
# 25   1087    23002  ...              sq s+cc x    1087
# 26   1089    23014  ...                     al    1089
# 47   1116    23316  ...                     cc    1116
# 3    1123    23344  ...                     cc    1123
# 24   1129    23389  ...                   cc *    1129
# 1    1130    23404  ...                     cc    1130
# 7    1131    23406  ...                   cc x    1131
# 11   1138    23422  ...                   mo ?    1138
# 14   1143    23438  ...              fu cc+agg    1143
# 41   1163    23592  ...                    soc    1163
# 30   1164    23601  ...                     cc    1164
# 44    121     2743  ...                    soc     121
# 15    122     2744  ...                    soc     122
# ...

# %% [markdown]
# #### Explanations

# %%
round(duration/n_ticks,2)
# Out:
# 0.03

# %%
duration
# Out:
# 0.12

# %%
myticks
# Out:
# array([0.  , 0.03, 0.06, 0.09])

# %%
#duration
df.loc[ori_rownum,'duration']
# Out:
# 0.11800000000000001

# %%
# duration check
print("datapoints: ",df.loc[ori_rownum,'raw_audio'].shape[0])
print("sr: ",df.loc[ori_rownum,'samplerate_hz'])
print(df.loc[ori_rownum,'raw_audio'].shape[0] / df.loc[ori_rownum,'samplerate_hz'])
# Out:
# datapoints:  944
# sr:  8000
# 0.118

# %%
print(0.03*8000) # number of audio frames that go in one fft
print((0.03*8000)/8) # n of audio frames between successive ffts

print(944 / ((0.03*8000)/8)) #nframes -> 37? more or less.
# Out:
# 240.0
# 30.0
# 31.466666666666665

# %% [markdown]
# Number of time frames is the same between soundfoc and regular, because we have adapted hop_length to the sampling rate.
#
# n. of timeframes = n. of total datapoints / hop_length
#
# where n. of timeframes is duration * sr and we use FFT_HOP * sr as hop_length.
#
# --> For a total of (duration * sr) datapoints, we compute FFTs with (FFT_HOP * sr) datapoints each thus receive (duration * sr)/(FFT_HOP * sr) time frames, which is therefore independent of sr and simply duration/FFT_HOP.

# %%
FFT_WIN = 0.03
FFT_HOP = FFT_WIN/8
print(0.118/FFT_HOP)
# Out:
# 31.466666666666665

# %%
FFT_HOP*spec.shape[1]
# Out:
# 0.12
