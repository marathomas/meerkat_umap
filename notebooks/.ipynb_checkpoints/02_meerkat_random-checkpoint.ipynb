# %% [markdown]
# # UMAP from random distance matrix

# %% [markdown]
# ### Installing and loading libraries

# %%
import os
import pandas as pd
import sys
import numpy as np
from pandas.core.common import flatten
import pickle
import umap
from pathlib import Path
import datetime
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import random

# %%
from plot_functions import umap_2Dplot, mara_3Dplot, plotly_viz
from preprocessing_functions import pad_spectro, calc_zscore
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# ### Setting constants

# %% [markdown]
# Setting project, input and output folders.

# %%
wd = os.getcwd()

DATA = os.path.join(os.path.sep, str(Path(wd).parents[0]), "data", "processed")
FIGURES = os.path.join(os.path.sep, str(Path(wd).parents[0]), "reports", "figures")

DF_DICT = {}
for dftype in ['full', 'reduced', 'balanced']:
    DF_DICT[dftype] = os.path.join(os.path.sep, DATA, "df_focal_"+dftype+".pkl")

# %% [markdown]
# # UMAP projection

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Choose dataset

# %%
dftype='reduced'
spec_df = pd.read_pickle(DF_DICT[dftype])
spec_df.shape
# Out:
# (6430, 29)

# %% [markdown]
# ### Choose feature

# %%
specs = spec_df.spectrograms.copy()

# normalize feature
specs = [calc_zscore(x) for x in specs] 

# pad feature
maxlen= np.max([spec.shape[1] for spec in specs])
flattened_specs = [pad_spectro(spec, maxlen).flatten() for spec in specs]
data = np.asarray(flattened_specs)
data.shape
# Out:
# (6430, 5360)

# %%
distmat = squareform(pdist(data, metric='euclidean'))

# %%
flattened_dists = distmat[np.triu_indices(n=distmat.shape[0], k=1)]

# %%
random.seed(100)
np.random.shuffle(flattened_dists)
# Out:
# array([39.04329978, 67.50863495, 60.99881576, ..., 53.86534023,
#        53.75780738, 57.50729285])

# %%
random_distmat = np.zeros(distmat.shape)
random_distmat[np.triu_indices(n=distmat.shape[0], k=1)] = flattened_dists

# %%
for i in range(random_distmat.shape[0]):
    for j in range(i,random_distmat.shape[1]):
        random_distmat[j,i] = random_distmat[i,j]

# %%
pd.DataFrame(random_distmat)
# Out:
#            0          1          2          3          4          5     \
# 0      0.000000  39.043300  67.508635  60.998816  60.865434  52.962199
# 1     39.043300   0.000000  57.578753  54.433247  46.037593  38.573887
# 2     67.508635  57.578753   0.000000  43.423702  34.069516  40.044479
# 3     60.998816  54.433247  43.423702   0.000000  46.273433  45.085391
# 4     60.865434  46.037593  34.069516  46.273433   0.000000  36.276302
# ...         ...        ...        ...        ...        ...        ...
# 6425  53.303482  47.650710  48.641267  43.118451  51.048776  47.049383
# 6426  39.973748  51.510404  56.566271  32.764947  40.136828  44.710046
# 6427  62.486704  33.934771  40.219608  56.755929  37.752572  34.167742
# 6428  57.627313  49.899342  48.159186  44.215181  30.453703  45.287311
# 6429  35.171123  26.261295  59.174162  48.201821  43.387182  54.072895
#
#            6          7          8          9     ...       6420       6421  \
# 0     62.238536  67.254686  45.779944  41.874412  ...  49.612397  40.821972
# 1     44.254990  45.386464  60.365793  32.629403  ...  67.098251  39.621697
# 2     49.591789  36.451149  46.493565  37.938224  ...  34.349636  71.388775
# 3     46.589074  46.288511  48.416395  55.181279  ...  56.280350  51.531351
# 4     47.032365  27.230865  52.508906  60.164498  ...  36.425203  45.856660
# ...         ...        ...        ...        ...  ...        ...        ...
# 6425  37.159748  54.159092  42.838917  38.762185  ...  51.215780  42.860497
# 6426  36.629587  46.713457  69.437497  27.060505  ...  37.656507  37.049442
# 6427  44.453131  57.173035  35.764904  35.063795  ...  41.703996  29.549202
# 6428  59.431641  55.310857  46.335011  40.750650  ...  42.663687  62.444898
# 6429  37.772157  44.645505  64.140150  42.719181  ...  69.157058  47.848086
#
#            6422       6423       6424       6425       6426       6427  \
# 0     48.349828  50.566183  49.747942  53.303482  39.973748  62.486704
# 1     49.609357  35.355447  66.473745  47.650710  51.510404  33.934771
# 2     43.864276  39.837655  46.632544  48.641267  56.566271  40.219608
# 3     45.726898  28.323126  41.728692  43.118451  32.764947  56.755929
# 4     26.209957  63.353868  37.220242  51.048776  40.136828  37.752572
# ...         ...        ...        ...        ...        ...        ...
# 6425  46.299273  48.281282  39.066994   0.000000  62.480051  58.642147
# 6426  39.340349  64.145506  19.963733  62.480051   0.000000  47.895280
# 6427  43.995482  35.573407  43.176339  58.642147  47.895280   0.000000
# 6428  67.087345  51.539943  41.189464  53.630917  33.525475  53.865340
# 6429  45.725964  39.411178  53.656114  41.208522  34.554521  53.757807
#
#            6428       6429
# 0     57.627313  35.171123
# 1     49.899342  26.261295
# 2     48.159186  59.174162
# 3     44.215181  48.201821
# 4     30.453703  43.387182
# ...         ...        ...
# 6425  53.630917  41.208522
# 6426  33.525475  34.554521
# 6427  53.865340  53.757807
# 6428   0.000000  57.507293
# 6429  57.507293   0.000000
#
# [6430 rows x 6430 columns]

# %%
# shuffle lower triangle

# %% [markdown]
# ## Run UMAP

# %%
#random_distmat = np.random.rand(data.shape[0],data.shape[0])

for i in range(random_distmat.shape[0]):
    for j in range(i,random_distmat.shape[0]):
        random_distmat[i,j] = random_distmat[j,i]

for i in range(random_distmat.shape[0]):
    random_distmat[i,i] = 0

reducer = umap.UMAP(n_components=3, min_dist=0, metric='precomputed', random_state=2204)
embedding = reducer.fit_transform(random_distmat)

reducer = umap.UMAP(n_components=2, min_dist=0, metric='precomputed', random_state=2204)
embedding2D = reducer.fit_transform(random_distmat)
# Out:
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/umap/umap_.py:1736: UserWarning: using precomputed metric; transform will be unavailable for new data and inverse_transform will be unavailable for all data
#   "using precomputed metric; transform will be unavailable for new data and inverse_transform "
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/umap/umap_.py:1736: UserWarning: using precomputed metric; transform will be unavailable for new data and inverse_transform will be unavailable for all data
#   "using precomputed metric; transform will be unavailable for new data and inverse_transform "

# %% [markdown]
# ## Visualization

# %%
labels = spec_df.call_lable.values
pal="Set2"

# %% [markdown]
# ### 2D Plots

# %%
outname = os.path.join(os.path.sep, FIGURES, 'UMAP_2D_plot_'+dftype+'_RANDOM_nolegend.jpg')
print(outname)
umap_2Dplot(embedding2D[:,0], embedding2D[:,1], labels, pal, outname=outname, showlegend=False)
# Out:
# /home/mthomas/Documents/MPI_work/projects/meerkat/meerkat_umap_pv/reports/figures/UMAP_2D_plot_reduced_RANDOM_nolegend.jpg

# %% [markdown]
# ### 3D Plot

# %% [markdown]
# #### Matplotlib

# %%
outname = os.path.join(os.path.sep, FIGURES, 'UMAP_3D_plot_'+dftype+'_RANDOM_nolegend.jpg')
print(outname)

mara_3Dplot(embedding[:,0],
            embedding[:,1],
            embedding[:,2],
            labels,
            pal,
            outname,
            showlegend=False)
# Out:
# /home/mthomas/Documents/MPI_work/projects/meerkat/meerkat_umap_pv/reports/figures/UMAP_3D_plot_reduced_RANDOM_nolegend.jpg

# %% [markdown]
# ## Save embedding

# %%
outname = os.path.join(os.path.sep, DATA,'basic_UMAP_'+dftype+'_default_params_RANDOM.csv')
np.savetxt(outname, embedding, delimiter=";")
print(outname)
# Out:
# /home/mthomas/Documents/MPI_work/projects/meerkat/meerkat_umap_pv/data/processed/basic_UMAP_reduced_default_params_RANDOM.csv

# %% [markdown]
# # Embedding evaluation

# %% [markdown]
# Evaluate the embedding based on calltype labels of nearest neighbors.

# %%
from evaluation_functions import nn, sil, plot_within_without

# %%
nn_stats = nn(embedding, np.asarray(labels), k=5)

# %%
nn_stats.get_statstab()
# Out:
#               agg         al         cc        ld         mo         sn  \
# agg      6.933333   9.066667  22.133333  2.346667  13.226667  28.426667
# al       4.984520  10.247678  24.272446  2.848297  12.043344  28.173375
# cc       5.402844  10.440081  23.967502  2.626947  12.213947  27.203791
# ld       6.707317  11.707317  24.512195  2.439024  10.121951  27.926829
# mo       6.613966   9.986825  23.715415  2.187088  10.619236  28.642951
# sn       5.692722   9.692722  22.598383  2.619946  12.140162  28.819407
# soc      5.701906   9.982669  23.414211  2.253033  11.889081  28.734835
# overall  5.832037  10.046656  22.970451  2.550544  11.804044  28.849145
#
#                soc
# agg      17.866667
# al       17.430341
# cc       18.144888
# ld       16.585366
# mo       18.234519
# sn       18.436658
# soc      18.024263
# overall  17.947123

# %%
nn_stats.get_statstabnorm()
# Out:
#           agg        al        cc        ld        mo        sn       soc
# agg  0.249549 -0.148071 -0.053558 -0.120192  0.164168 -0.021284 -0.006482
# al  -0.226545  0.028582  0.079540  0.159295  0.028955 -0.034196 -0.042152
# cc  -0.110281  0.055418  0.061300  0.042582  0.049248 -0.084721  0.015811
# ld   0.201736  0.220695  0.093721 -0.064501 -0.221794 -0.046877 -0.113842
# mo   0.181516 -0.008617  0.046046 -0.221794 -0.152601 -0.010348  0.022920
# sn  -0.034881 -0.051742 -0.023560  0.038732  0.040506 -0.001488  0.038825
# soc -0.032556 -0.009218  0.027605 -0.178937  0.010356 -0.005728  0.006188

# %% [markdown]
# ## Calculate metrics

# %%
print("Log final metric (unweighted):",nn_stats.get_S())
print("Abs final metric (unweighted):",nn_stats.get_Snorm())
# Out:
# Log final metric (unweighted): 14.435777673004159
# Abs final metric (unweighted): 0.018146970390030662

# %%
outname = os.path.join(os.path.sep, FIGURES, 'heatS_UMAP_'+dftype+'_RANDOM.png')
print(outname)

nn_stats.plot_heat_S(outname=outname)
# Out:
# /home/mthomas/Documents/MPI_work/projects/meerkat/meerkat_umap_pv/reports/figures/heatS_UMAP_reduced_RANDOM.png

# %%
outname = os.path.join(os.path.sep, FIGURES, 'heatSnorm_UMAP_'+dftype+'_RANDOM.png')
outname=None
#print(outname)

nn_stats.plot_heat_Snorm(outname=outname)

# %%
outname = os.path.join(os.path.sep, FIGURES, 'heatfold_UMAP_'+dftype+'_RANDOM.png')
outname=None
#print(outname)

nn_stats.plot_heat_fold(outname=outname)

# %% [markdown]
# # Within vs. outside distances

# %%
plot_within_without(embedding=embedding, labels=labels, outname="distanceswithinwithout_reduced_RANDOM.png")

# %% [markdown]
# ## Silhouette Plot

# %%
sil_stats = sil(embedding, labels)
sil_stats.plot_sil()

# %% [markdown]
# # Graph from embedding evaluation

# %% [markdown]
# Resource: https://en.it1352.com/article/d096c1eadbb84c19b038eb9648153346.html

# %%
#embedding_filename = 'basic_UMAP_'+dftype+'_default_params_RANDOM.csv'
#embedding = np.loadtxt(os.path.join(os.path.sep, DATA, embedding_filename),delimiter=";")

# %%
outname = os.path.join(os.path.sep,FIGURES,'simgraph_RANDOM.png')
nn_stats.draw_simgraph(outname)
# Out:
# Graph saved at  /home/mthomas/Documents/MPI_work/projects/meerkat/meerkat_umap_pv/reports/figures/simgraph_RANDOM.png
