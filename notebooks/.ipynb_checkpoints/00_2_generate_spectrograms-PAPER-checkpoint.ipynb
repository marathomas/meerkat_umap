# %% [markdown]
# # Generate spectrograms

# %% [markdown]
# Script to generate spectrogram from raw audio for each call.

# %%
import pandas as pd
import os
import librosa
import sys
import numpy as np
import pickle
from pathlib import Path
import librosa.display
import matplotlib.pyplot as plt

# %%
from spectrogramming_functions import generate_mel_spectrogram, generate_stretched_mel_spectrogram, generate_freq_spectrogram, generate_ampli_spectrogram

# %%
wd = os.getcwd()

DATA = os.path.join(os.path.sep, str(Path(wd).parents[0]), "data", "processed")
RAW_DATA = os.path.join(os.path.sep, str(Path(wd).parents[0]), "data", "raw")
DF_FULL = os.path.join(os.path.sep, DATA, "meerkat_full_audio.pkl")

# %%
# Spectrogramming parameters
FFT_WIN = 0.03 # FFT_WIN*samplerate = length of fft/n_fft (number of audio frames that go in one fft)
FFT_HOP = FFT_WIN/8 # FFT_HOP*samplerate = n of audio frames between successive ffts
N_MELS = 40 # number of mel bins
WINDOW = 'hann' # each frame of audio is windowed by a window function (its length can also be
# determined and is then padded with zeros to match n_fft. we use window_length = length of fft
FMAX = 4000
N_MFCC = 13

# %% [markdown]
# # Read in data

# %%
df = pd.read_pickle(DF_FULL)
df.shape
# Out:
# (34955, 25)

# %% [markdown]
# # Generate spectrogram columns

# %%
df.samplerate_hz.value_counts()
# Out:
# 8000     30087
# 48000     4868
# Name: samplerate_hz, dtype: int64

# %%
spectrograms = df.apply(lambda row: generate_mel_spectrogram(row['raw_audio'],
                                                             row['samplerate_hz'],
                                                             N_MELS,
                                                             WINDOW,
                                                             FFT_WIN,
                                                             FFT_HOP,
                                                             FMAX), 
                        axis=1)


df['spectrograms'] = spectrograms

denoised = [(spectrogram - np.median(spectrogram, axis=0)) for spectrogram in df['spectrograms']]
df['denoised_spectrograms'] = denoised
# Out:
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=208
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=152
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=224
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=200
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=192
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=232
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=112
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=184
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=168
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=216
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=120
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=176
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=144
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=160
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=96
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=72
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=104
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=128
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=136
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=88
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=56
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=80
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=64
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=48
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1296
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1104
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1200
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=431
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1152
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1392
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1344
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1248
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1008
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=912
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=816
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=960
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=288
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=384
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=528
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1056
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=672
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=863
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=720
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=768
#   n_fft, y.shape[-1]

# %%
# Show example spectrograms

# %%
df_subset = df.sample(n=25)
specs = df_subset.spectrograms.values

plt.figure(figsize=(8, 8))
for i,spec in enumerate(specs,1):
    plt.subplot(5, 5, i)
    librosa.display.specshow(spec)
    plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

# %%
plt.figure(figsize=(8, 8))
for i,spec in enumerate(specs,1):
    plt.subplot(5, 5, i)
    plt.imshow(spec, interpolation='nearest', origin='lower', aspect='auto')
    plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

# %% [markdown]
# # Generate stretched spectrograms

# %%
#df = pd.read_pickle(os.path.join(os.path.sep, DATA, "df_focal.pkl"))

# %%
MAX_DURATION = 0.5

# %%
spectrograms = df.apply(lambda row: generate_stretched_mel_spectrogram(row['raw_audio'],
                                                                       row['samplerate_hz'], 
                                                                       row['duration_s'],
                                                                       N_MELS,
                                                                       WINDOW,
                                                                       FFT_WIN,
                                                                       FFT_HOP,
                                                                       MAX_DURATION),
                        axis=1)

df['stretched_spectrograms'] = spectrograms
df['stretched_denoised_spectrograms'] = [(spectrogram - np.median(spectrogram, axis=0)) for spectrogram in df['stretched_spectrograms']]

# %% [markdown]
# # Generate MFCCs

# %%
from preprocessing_functions import calc_zscore

# %%
mfccs = [librosa.feature.mfcc(S=spectro,n_mfcc=N_MFCC) for spectro in df['stretched_spectrograms']]
df['stretched_mfccs'] = mfccs

# %%
mfccs = [librosa.feature.mfcc(S=spectro,n_mfcc=N_MFCC) for spectro in df['spectrograms']]
df['mfccs'] = mfccs

# %%
specs = [calc_zscore(s) for s in df.spectrograms]
zmfccs = [librosa.feature.mfcc(S=spectro, n_mfcc=N_MFCC) for spectro in specs]
df['zmfccs'] = zmfccs

# %% [markdown]
# # Generate spectrograms on frequency scale

# %%
freq_spectrograms = df.apply(lambda row: generate_freq_spectrogram(row['raw_audio'],
                                                                   row['samplerate_hz'],
                                                                   WINDOW,
                                                                   FFT_WIN,
                                                                   FFT_HOP),
                             axis=1)


df['freq_spectrograms'] = freq_spectrograms
# Out:
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=208
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=152
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=224
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=200
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=192
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=232
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=112
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=184
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=168
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=216
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=120
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=176
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=144
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=160
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=96
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=72
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=104
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=128
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=136
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=88
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=56
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=80
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=64
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=240 is too small for input signal of length=48
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1296
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1104
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1200
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=431
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1152
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1392
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1344
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1248
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1008
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=912
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=816
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=960
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=288
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=384
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=528
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=1056
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=672
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=863
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=720
#   n_fft, y.shape[-1]
# /home/mthomas/anaconda3/envs/meerkat_umap_env_3/lib/python3.7/site-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1440 is too small for input signal of length=768
#   n_fft, y.shape[-1]

# %%
shapes = [s.shape[0] for s in df.freq_spectrograms]
pd.Series(shapes).value_counts()
# Out:
# 121    30087
# 721     4868
# dtype: int64

# %% [markdown]
# Because of different sampling rate, resulting spectrograms have different range of frequency. Resolution is the same, but range is different.
# See this for explanations:
# http://localhost:8888/notebooks/Documents/MPI_work/projects/meerkat/master_thesis_analysis/meerkat_code/Spectrogram_Params.ipynb

# %%
freq_specs = [x[:121,:] if x.shape[0]==721 else x for x in df.freq_spectrograms]
df['freq_spectrograms'] = freq_specs

# %%
shapes = [s.shape[0] for s in df.freq_spectrograms]
pd.Series(shapes).value_counts()
# Out:
# 121    34955
# dtype: int64

# %%
df_subset = df.sample(n=25)
specs = df_subset.freq_spectrograms.values

plt.figure(figsize=(8, 8))
for i,spec in enumerate(specs,1):
    plt.subplot(5, 5, i)
    #librosa.display.specshow(spec)
    plt.imshow(spec, interpolation='nearest', origin='lower', aspect='auto')
    plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

# %%
specs = df_subset.spectrograms.values

plt.figure(figsize=(8, 8))
for i,spec in enumerate(specs,1):
    plt.subplot(5, 5, i)
    #librosa.display.specshow(spec)
    plt.imshow(spec, interpolation='nearest', origin='lower', aspect='auto')
    plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

# %% [markdown]
# # Generate spectrograms on magnitude scale

# %%
ampli_specs = df.apply(lambda row: generate_ampli_spectrogram(row['raw_audio'],
                                                               row['samplerate_hz'],
                                                               WINDOW,
                                                               FFT_WIN,
                                                               FFT_HOP),
                             axis=1)

df['ampli_spectrograms'] = ampli_specs

# %%
shapes = [s.shape[0] for s in df.ampli_spectrograms]
pd.Series(shapes).value_counts()
# Out:
# 121    30087
# 721     4868
# dtype: int64

# %%
ampli_specs = [x[:121,:] if x.shape[0]==721 else x for x in df.ampli_spectrograms]
df['ampli_spectrograms'] = ampli_specs
shapes = [s.shape[0] for s in df.ampli_spectrograms]
pd.Series(shapes).value_counts()
# Out:
# 121    34955
# dtype: int64

# %%
df_subset = df.sample(n=25)
specs = df_subset.ampli_spectrograms.values

plt.figure(figsize=(8, 8))
for i,spec in enumerate(specs,1):
    plt.subplot(5, 5, i)
    #librosa.display.specshow(spec)
    plt.imshow(spec, interpolation='nearest', origin='lower', aspect='auto')
    plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

# %% [markdown]
# # Save full labelfile

# %%
df.columns
# Out:
# Index(['Name', 'Start', 'Duration', 'Time Format', 'Type', 'Description',
#        'start_s', 'duration_s', 'stop_s', 'date', 'samplerate_hz', 'indv',
#        'original_wav', 'bout_number', 'Time.Format', 'call_lable',
#        'unsure_call', 'noisy', 'certain_yn', 'soundfoc_yn', 'nonfocal_yn',
#        'callID', 'Sex', 'status', 'raw_audio', 'spectrograms',
#        'denoised_spectrograms', 'stretched_spectrograms',
#        'stretched_denoised_spectrograms', 'stretched_mfccs', 'mfccs', 'zmfccs',
#        'freq_spectrograms', 'ampli_spectrograms'],
#       dtype='object')

# %%
df.to_pickle(os.path.join(os.path.sep, DATA, "meerkat_full_specs.pkl"))
